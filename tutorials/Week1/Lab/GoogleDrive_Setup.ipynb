# %% [markdown]
# # **42028: Deep Learning and CNN**
#
# ### Google Drive Setup Script

# %% [markdown]
# ## Connect to your Google Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Create the Folder Structure for the Semester

# %%
cd /content/gdrive/MyDrive/42028/
# Out:
# /content/gdrive/MyDrive/42028 Version 2023

# %%
# !ls
# Out:
# Week1

# %%
# !mkdir 42028

# %%
cd 42028
# Out:
# /content/gdrive/MyDrive/42028 Version 2023/42028

# %%
# !ls

# %%
# Create the Folder Structure
import os
for weekCnt in range (1,12):
  dirName = "Week{}"
  dirName = dirName.format(weekCnt)
  if not os.path.exists(dirName):
    os.mkdir(dirName)
  else: 
    print(dirName +" Already exsits!")

# %%
cd Week1

# %%
# !mkdir OpenCV Python
